# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | susuman
# Processing Record 2 of Set 1 | badger
# Processing Record 3 of Set 1 | grytviken
# Processing Record 4 of Set 1 | namibe
# Processing Record 5 of Set 1 | saint-yrieix-la-perche
# Processing Record 6 of Set 1 | inhambane
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | bikenibeu village
# Processing Record 9 of Set 1 | garachico
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | palikir - national government center
# Processing Record 13 of Set 1 | kosh-agach
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | waitangi
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | kez
# Processing Record 20 of Set 1 | port pirie
# Processing Record 21 of Set 1 | college
# Processing Record 22 of Set 1 | katabu
# Processing Record 23 of Set 1 | pariaman
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | constantia
# Processing Record 26 of Set 1 | olonkinbyen
# Processing Record 27 of Set 1 | tolanaro
# Processing Record 28 of Set 1 | fale old settlement
# Processing Record 29 of Set 1 | malango
# Processing Record 30 of Set 1 | fortuna
# Processing Record 31 of Set 1 | kailua-kona
# Processing Record 32 of Set 1 | isafjordur
# Processing Record 33 of Set 1 | talnakh
# Processing Record 34 of Set 1 | happy valley-goose bay
# Processing Record 35 of Set 1 | anadyr
# Processing Record 36 of Set 1 | coahuayana de hidalgo
# Processing Record 37 of Set 1 | richards bay
# Processing Record 38 of Set 1 | blackmans bay
# Processing Record 39 of Set 1 | nar'yan-mar
# Processing Record 40 of Set 1 | lobujya
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | enewetak
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | benson
# Processing Record 45 of Set 1 | belyy yar
# Processing Record 46 of Set 1 | valledupar
# Processing Record 47 of Set 1 | santa rosa del sara
# Processing Record 48 of Set 1 | yasuj
# Processing Record 49 of Set 1 | severo-yeniseyskiy
# Processing Record 50 of Set 1 | sault ste. marie
# Processing Record 0 of Set 2 | georgetown
# Processing Record 1 of Set 2 | pervomayskoye
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | port mathurin
# Processing Record 5 of Set 2 | hobyo
# Processing Record 6 of Set 2 | margaret river
# Processing Record 7 of Set 2 | kapuskasing
# Processing Record 8 of Set 2 | invercargill
# Processing Record 9 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 10 of Set 2 | zaozersk
# Processing Record 11 of Set 2 | thisted
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | afaahiti
# Processing Record 14 of Set 2 | oyama
# Processing Record 15 of Set 2 | arkhangel'sk
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | saltburn-by-the-sea
# Processing Record 18 of Set 2 | condado
# Processing Record 19 of Set 2 | daru
# Processing Record 20 of Set 2 | kourou
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | kingston
# Processing Record 24 of Set 2 | kachug
# Processing Record 25 of Set 2 | marka
# Processing Record 26 of Set 2 | ganghwa-gun
# Processing Record 27 of Set 2 | flying fish cove
# Processing Record 28 of Set 2 | betio village
# Processing Record 29 of Set 2 | lobito
# Processing Record 30 of Set 2 | paita
# Processing Record 31 of Set 2 | ban phe
# City not found. Skipping...
# Processing Record 32 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 33 of Set 2 | tazovsky
# Processing Record 34 of Set 2 | labytnangi
# Processing Record 35 of Set 2 | oyon
# Processing Record 36 of Set 2 | bilibino
# Processing Record 37 of Set 2 | atherton
# Processing Record 38 of Set 2 | boguchany
# Processing Record 39 of Set 2 | saint-paul
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | carutapera
# Processing Record 42 of Set 2 | phitsanulok
# Processing Record 43 of Set 2 | bopolu
# Processing Record 44 of Set 2 | aykhal
# Processing Record 45 of Set 2 | puerto natales
# Processing Record 46 of Set 2 | gidam
# Processing Record 47 of Set 2 | canoinhas
# Processing Record 48 of Set 2 | punta arenas
# Processing Record 49 of Set 2 | port lincoln
# Processing Record 0 of Set 3 | amasra
# Processing Record 1 of Set 3 | mandalgovi
# Processing Record 2 of Set 3 | sevastopol
# Processing Record 3 of Set 3 | richmond
# Processing Record 4 of Set 3 | west island
# Processing Record 5 of Set 3 | villa gesell
# Processing Record 6 of Set 3 | edinburgh of the seven seas
# Processing Record 7 of Set 3 | lihue
# Processing Record 8 of Set 3 | nikolayevsk-on-amure
# Processing Record 9 of Set 3 | behshahr
# Processing Record 10 of Set 3 | port macquarie
# Processing Record 11 of Set 3 | luderitz
# Processing Record 12 of Set 3 | stanley
# Processing Record 13 of Set 3 | mount gambier
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | minas de marcona
# Processing Record 16 of Set 3 | tura
# Processing Record 17 of Set 3 | senanga
# Processing Record 18 of Set 3 | alvorada
# Processing Record 19 of Set 3 | musay'id
# City not found. Skipping...
# Processing Record 20 of Set 3 | laikit, laikit ii (dimembe)
# Processing Record 21 of Set 3 | papatowai
# Processing Record 22 of Set 3 | serdar
# Processing Record 23 of Set 3 | odorheiu secuiesc
# Processing Record 24 of Set 3 | high peak
# City not found. Skipping...
# Processing Record 25 of Set 3 | marovoay
# Processing Record 26 of Set 3 | la passe
# Processing Record 27 of Set 3 | egilsstadir
# Processing Record 28 of Set 3 | haiku-pauwela
# Processing Record 29 of Set 3 | kattivakkam
# Processing Record 30 of Set 3 | holualoa
# Processing Record 31 of Set 3 | fort st. john
# Processing Record 32 of Set 3 | gadzhiyevo
# Processing Record 33 of Set 3 | spring
# Processing Record 34 of Set 3 | mahajanga
# Processing Record 35 of Set 3 | la'ie
# Processing Record 36 of Set 3 | labrador city
# Processing Record 37 of Set 3 | kuybyshevo
# Processing Record 38 of Set 3 | sao joao da barra
# Processing Record 39 of Set 3 | jabor
# Processing Record 40 of Set 3 | kruisfontein
# Processing Record 41 of Set 3 | avarua
# Processing Record 42 of Set 3 | ciudad dario
# Processing Record 43 of Set 3 | diffa
# Processing Record 44 of Set 3 | caleta de carquin
# Processing Record 45 of Set 3 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 46 of Set 3 | graulhet
# Processing Record 47 of Set 3 | puerto armuelles
# Processing Record 48 of Set 3 | minab
# Processing Record 49 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 0 of Set 4 | st. john's
# Processing Record 1 of Set 4 | bethanie
# Processing Record 2 of Set 4 | severomorsk
# Processing Record 3 of Set 4 | kapa'a
# Processing Record 4 of Set 4 | usinsk
# Processing Record 5 of Set 4 | puerto baquerizo moreno
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | ola
# Processing Record 8 of Set 4 | mili
# Processing Record 9 of Set 4 | merizo village
# Processing Record 10 of Set 4 | international falls
# Processing Record 11 of Set 4 | katsuren-haebaru
# Processing Record 12 of Set 4 | yankton
# Processing Record 13 of Set 4 | hadibu
# Processing Record 14 of Set 4 | dudinka
# Processing Record 15 of Set 4 | nizhnesortymskiy
# Processing Record 16 of Set 4 | saipan
# Processing Record 17 of Set 4 | vila velha
# Processing Record 18 of Set 4 | howard springs
# Processing Record 19 of Set 4 | karratha
# Processing Record 20 of Set 4 | uturoa
# Processing Record 21 of Set 4 | zalingei
# Processing Record 22 of Set 4 | yeppoon
# Processing Record 23 of Set 4 | salihli
# Processing Record 24 of Set 4 | suntar
# Processing Record 25 of Set 4 | freetown
# Processing Record 26 of Set 4 | nantucket
# Processing Record 27 of Set 4 | vilhena
# Processing Record 28 of Set 4 | villa bruzual
# Processing Record 29 of Set 4 | atafu village
# Processing Record 30 of Set 4 | roma
# Processing Record 31 of Set 4 | waingapu
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | wailua homesteads
# Processing Record 34 of Set 4 | east london
# Processing Record 35 of Set 4 | hawaiian paradise park
# Processing Record 36 of Set 4 | palmer
# Processing Record 37 of Set 4 | alice springs
# Processing Record 38 of Set 4 | hermanus
# Processing Record 39 of Set 4 | kodinsk
# Processing Record 40 of Set 4 | singkil
# Processing Record 41 of Set 4 | shchuchyn
# Processing Record 42 of Set 4 | ibarreta
# Processing Record 43 of Set 4 | timmins
# Processing Record 44 of Set 4 | udachny
# Processing Record 45 of Set 4 | sinop
# Processing Record 46 of Set 4 | chonchi
# Processing Record 47 of Set 4 | berkovitsa
# Processing Record 48 of Set 4 | tashir
# Processing Record 49 of Set 4 | lubango
# Processing Record 0 of Set 5 | sisimiut
# Processing Record 1 of Set 5 | santa ana
# Processing Record 2 of Set 5 | gunjur
# Processing Record 3 of Set 5 | punta del este
# Processing Record 4 of Set 5 | vecindario
# City not found. Skipping...
# Processing Record 5 of Set 5 | zaigrayevo
# Processing Record 6 of Set 5 | saint-philippe
# Processing Record 7 of Set 5 | nemuro
# Processing Record 8 of Set 5 | guerrero negro
# Processing Record 9 of Set 5 | kataragama
# City not found. Skipping...
# Processing Record 10 of Set 5 | dedovichi
# Processing Record 11 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 12 of Set 5 | rioblanco
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | aleg
# Processing Record 15 of Set 5 | banda aceh
# Processing Record 16 of Set 5 | carnarvon
# Processing Record 17 of Set 5 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 18 of Set 5 | juegang
# Processing Record 19 of Set 5 | pionerskiy
# Processing Record 20 of Set 5 | cumberland
# Processing Record 21 of Set 5 | altai
# Processing Record 22 of Set 5 | el granada
# Processing Record 23 of Set 5 | harper
# Processing Record 24 of Set 5 | ust'-kut
# Processing Record 25 of Set 5 | alaghsas
# Processing Record 26 of Set 5 | vorgashor
# Processing Record 27 of Set 5 | puerto deseado
# Processing Record 28 of Set 5 | ilulissat
# Processing Record 29 of Set 5 | miyanoura
# City not found. Skipping...
# Processing Record 30 of Set 5 | cidade velha
# Processing Record 31 of Set 5 | playa vicente
# Processing Record 32 of Set 5 | omaruru
# Processing Record 33 of Set 5 | ghadamis
# Processing Record 34 of Set 5 | ulldecona
# Processing Record 35 of Set 5 | umm kaddadah
# Processing Record 36 of Set 5 | robit
# Processing Record 37 of Set 5 | rouissat
# Processing Record 38 of Set 5 | basoko
# Processing Record 39 of Set 5 | glace bay
# Processing Record 40 of Set 5 | pimentel
# Processing Record 41 of Set 5 | horn
# Processing Record 42 of Set 5 | vidyayevo
# Processing Record 43 of Set 5 | taulaga
# Processing Record 44 of Set 5 | outjo
# Processing Record 45 of Set 5 | el chorrillo
# Processing Record 46 of Set 5 | dourados
# Processing Record 47 of Set 5 | fort mcmurray
# Processing Record 48 of Set 5 | hammerfest
# Processing Record 49 of Set 5 | sola
# Processing Record 0 of Set 6 | atmore
# Processing Record 1 of Set 6 | lerwick
# Processing Record 2 of Set 6 | samthar
# Processing Record 3 of Set 6 | mata-utu
# Processing Record 4 of Set 6 | alo
# Processing Record 5 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 6 of Set 6 | kyshtovka
# Processing Record 7 of Set 6 | dolisie
# Processing Record 8 of Set 6 | lata
# Processing Record 9 of Set 6 | bonthe
# Processing Record 10 of Set 6 | klyuchi
# Processing Record 11 of Set 6 | stettler
# Processing Record 12 of Set 6 | miranda
# Processing Record 13 of Set 6 | utrik
# Processing Record 14 of Set 6 | santa cruz
# Processing Record 15 of Set 6 | taltal
# Processing Record 16 of Set 6 | miyako
# Processing Record 17 of Set 6 | bandarbeyla
# Processing Record 18 of Set 6 | lepsy
# Processing Record 19 of Set 6 | codajas
# Processing Record 20 of Set 6 | datong
# Processing Record 21 of Set 6 | dampit
# Processing Record 22 of Set 6 | hilo
# Processing Record 23 of Set 6 | iskateley
# Processing Record 24 of Set 6 | giridih
# Processing Record 25 of Set 6 | lompoc
# Processing Record 26 of Set 6 | whitehorse
# Processing Record 27 of Set 6 | touros
# Processing Record 28 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 29 of Set 6 | fada
# Processing Record 30 of Set 6 | sebastopol
# Processing Record 31 of Set 6 | okhotsk
# Processing Record 32 of Set 6 | qarauyl
# Processing Record 33 of Set 6 | sleaford
# Processing Record 34 of Set 6 | adrar
# Processing Record 35 of Set 6 | castillos
# Processing Record 36 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 6 | pacific grove
# Processing Record 38 of Set 6 | north haven
# Processing Record 39 of Set 6 | fredericton
# Processing Record 40 of Set 6 | faranah
# Processing Record 41 of Set 6 | negombo
# Processing Record 42 of Set 6 | barcelos
# Processing Record 43 of Set 6 | nablus
# Processing Record 44 of Set 6 | ebon
# Processing Record 45 of Set 6 | pico truncado
# Processing Record 46 of Set 6 | bartica
# Processing Record 47 of Set 6 | york beach
# Processing Record 48 of Set 6 | san antonio de pale
# Processing Record 49 of Set 6 | firuzabad
# Processing Record 0 of Set 7 | arraial do cabo
# Processing Record 1 of Set 7 | amga
# Processing Record 2 of Set 7 | sao vicente
# Processing Record 3 of Set 7 | alofi
# Processing Record 4 of Set 7 
# Processing Record 14 of Set 10 | lagoa
# Processing Record 15 of Set 10 | padang
# Processing Record 16 of Set 10 | vezirkopru
# Processing Record 17 of Set 10 | sitka
# Processing Record 18 of Set 10 | new plymouth
# Processing Record 19 of Set 10 | chimore
# Processing Record 20 of Set 10 | fuerte olimpo
# Processing Record 21 of Set 10 | grootfontein
# Processing Record 22 of Set 10 | mejit
# Processing Record 23 of Set 10 | greenville
# Processing Record 24 of Set 10 | levuka
# Processing Record 25 of Set 10 | villas de irapuato
# City not found. Skipping...
# Processing Record 26 of Set 10 | maitum
# Processing Record 27 of Set 10 | narvik
# Processing Record 28 of Set 10 | kasaragod
# Processing Record 29 of Set 10 | letlhakane
# Processing Record 30 of Set 10 | dharchula
# Processing Record 31 of Set 10 | tromso
# Processing Record 32 of Set 10 | high river
# Processing Record 33 of Set 10 | bacabal
# Processing Record 34 of Set 10 | daultala
# Processing Record 35 of Set 10 | opuwo
# Processing Record 36 of Set 10 | frederico westphalen
# Processing Record 37 of Set 10 | west helena
# Processing Record 38 of Set 10 | saiha
# Processing Record 39 of Set 10 | kone
# Processing Record 40 of Set 10 | acarau
# Processing Record 41 of Set 10 | ridgecrest
# Processing Record 42 of Set 10 | al mijlad
# Processing Record 43 of Set 10 | ariquemes
# Processing Record 44 of Set 10 | belmonte
# Processing Record 45 of Set 10 | aioun
# Processing Record 46 of Set 10 | fort bragg
# Processing Record 47 of Set 10 | papao
# Processing Record 48 of Set 10 | pandan
# Processing Record 49 of Set 10 | kishtwar
# Processing Record 0 of Set 11 | salmon arm
# Processing Record 1 of Set 11 | sainte-marie
# Processing Record 2 of Set 11 | senador guiomard
# Processing Record 3 of Set 11 | kroya
# Processing Record 4 of Set 11 | churapcha
# Processing Record 5 of Set 11 | media luna
# Processing Record 6 of Set 11 | at taj
# Processing Record 7 of Set 11 | baud
# Processing Record 8 of Set 11 | phan thiet
# Processing Record 9 of Set 11 | nema
# Processing Record 10 of Set 11 | al jawf
# Processing Record 11 of Set 11 | saint-jean-de-monts
# Processing Record 12 of Set 11 | tougan
# Processing Record 13 of Set 11 | tazacorte
# Processing Record 14 of Set 11 | faya-largeau
# Processing Record 15 of Set 11 | trstena
# Processing Record 16 of Set 11 | crane
# Processing Record 17 of Set 11 | saint-pierre
# Processing Record 18 of Set 11 | pyapon
# Processing Record 19 of Set 11 | suva
# Processing Record 20 of Set 11 | laojunmiao
# Processing Record 21 of Set 11 | sinabang
# Processing Record 22 of Set 11 | asau village
# City not found. Skipping...
# Processing Record 23 of Set 11 | miquelon
# Processing Record 24 of Set 11 | yanchep
# Processing Record 25 of Set 11 | tsiombe
# Processing Record 26 of Set 11 | elmendorf air force base
# City not found. Skipping...
# Processing Record 27 of Set 11 | molina
# Processing Record 28 of Set 11 | san luis de la loma
# Processing Record 29 of Set 11 | nagqu
# Processing Record 30 of Set 11 | codrington
# Processing Record 31 of Set 11 | ploudalmezeau
# Processing Record 32 of Set 11 | usogorsk
# Processing Record 33 of Set 11 | salinas
# Processing Record 34 of Set 11 | priob'ye
# Processing Record 35 of Set 11 | port sudan
# Processing Record 36 of Set 11 | vallenar
# Processing Record 37 of Set 11 | kijang
# Processing Record 38 of Set 11 | leninskoye
# Processing Record 39 of Set 11 | puerto colombia
# Processing Record 40 of Set 11 | al azraq ash shamali
# City not found. Skipping...
# Processing Record 41 of Set 11 | batangafo
# Processing Record 42 of Set 11 | rio grande
# Processing Record 43 of Set 11 | sokolovyy
# Processing Record 44 of Set 11 | ulanhot
# Processing Record 45 of Set 11 | hennaya
# Processing Record 46 of Set 11 | montepuez
# Processing Record 47 of Set 11 | naze
# Processing Record 48 of Set 11 | espargos
# City not found. Skipping...
# Processing Record 49 of Set 11 | madhoganj
# Processing Record 0 of Set 12 | nelson bay
# Processing Record 1 of Set 12 | koratagere
# Processing Record 2 of Set 12 | saint-francois
# Processing Record 3 of Set 12 | xacmaz
# Processing Record 4 of Set 12 | sao sebastiao do paraiso
# Processing Record 5 of Set 12 | shengli
# Processing Record 6 of Set 12 | kralendijk
# Processing Record 7 of Set 12 | hayma'
# City not found. Skipping...
# Processing Record 8 of Set 12 | el calafate
# Processing Record 9 of Set 12 | karbala
# Processing Record 10 of Set 12 | nyamuswa
# Processing Record 11 of Set 12 | itaporanga
# Processing Record 12 of Set 12 | pemalang
# Processing Record 13 of Set 12 | duncan town
# City not found. Skipping...
# Processing Record 14 of Set 12 | ponta delgada
# Processing Record 15 of Set 12 | saudarkrokur
# Processing Record 16 of Set 12 | rongelap
# Processing Record 17 of Set 12 | jean-rabel
# Processing Record 18 of Set 12 | caister-on-sea
# Processing Record 19 of Set 12 | natal
# Processing Record 20 of Set 12 | weno
# Processing Record 21 of Set 12 | surgut
# Processing Record 22 of Set 12 | kayangel
# Processing Record 23 of Set 12 | newman
# Processing Record 24 of Set 12 | mount isa
# Processing Record 25 of Set 12 | valentin gomez farias
# Processing Record 26 of Set 12 | kotel'nich
# Processing Record 27 of Set 12 | moose jaw
# Processing Record 28 of Set 12 | vengurla
# Processing Record 29 of Set 12 | bayanaul
# Processing Record 30 of Set 12 | sur
# Processing Record 31 of Set 12 | pekanbaru
# Processing Record 32 of Set 12 | shibata
# Processing Record 33 of Set 12 | pursat
# Processing Record 34 of Set 12 | axim
# Processing Record 35 of Set 12 | coalcoman de vazquez pallares
# Processing Record 36 of Set 12 | swakopmund
# Processing Record 37 of Set 12 | mar del plata
# Processing Record 38 of Set 12 | zangguy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 susuman  62.7833  148.1667    -19.81        97         100
# 1                  badger  64.8000 -147.5333      2.14        91         100
# 2               grytviken -54.2811  -36.5092      2.15        96         100
# 3                  namibe -15.1961   12.1522     19.91        79           5
# 4  saint-yrieix-la-perche  45.5160    1.2057     15.03        93          76
#
#    Wind Speed Country        Date
# 0        0.20      RU  1729541744
# 1        1.54      US  1729541745
# 2        2.43      GS  1729541746
# 3        1.82      AO  1729541747
# 4        1.51      FR  1729541748

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       susuman  62.7833  148.1667    -19.81        97
# 1                        badger  64.8000 -147.5333      2.14        91
# 2                     grytviken -54.2811  -36.5092      2.15        96
# 3                        namibe -15.1961   12.1522     19.91        79
# 4        saint-yrieix-la-perche  45.5160    1.2057     15.03        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        0.20      RU  1729541744
# 1               100        1.54      US  1729541745
# 2               100        2.43      GS  1729541746
# 3                 5        1.82      AO  1729541747
# 4                76        1.51      FR  1729541748

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values, y_values, edgecolor='black')

# Incorporate the other graph properties
# Import datetime
from datetime import date

# Add labels, title, and grid
plt.title(f'City Max Latitude vs. Temperature ({date.today()})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values, y_values, edgecolor='black')

# Incorporate the other graph properties
# Add labels, title, and grid
plt.title(f'City Latitude vs. Humidity ({date.today()})')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values, y_values, edgecolor='black')

# Incorporate the other graph properties
# Add labels, title, and grid
plt.title(f'City Latitude vs. Cloudiness ({date.today()})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values, y_values, edgecolor='black')

# Incorporate the other graph properties
# Add labels, title, and grid
plt.title(f'City Latitude vs. Wind Speed ({date.today()})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg_plot(x_values, y_values, title, x_label, y_label):

    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    print(f"The r^2-value is: {r_value**2}")

    # Plot the data points and the linear regression model
    plt.scatter(x_values, y_values, label='Data Points')
    plt.plot(x_values, x_values * slope + intercept, 'r-', label='Fitted Line')

    # Add labels and title
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    # Format the equation string: y = mx + b
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Display the equation on the plot
    plt.annotate(line_eq, xy=(0.05, 0.05), xycoords='axes fraction', fontsize=15, color='red')

    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       susuman  62.7833  148.1667    -19.81        97
# 1                        badger  64.8000 -147.5333      2.14        91
# 4        saint-yrieix-la-perche  45.5160    1.2057     15.03        93
# 6                       iqaluit  63.7506  -68.5145     -2.15        86
# 7             bikenibeu village   1.3673  173.1241     28.98        74
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        0.20      RU  1729541744
# 1               100        1.54      US  1729541745
# 4                76        1.51      FR  1729541748
# 6                75        3.09      CA  1729541750
# 7                20        4.63      KI  1729541752

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"]<0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                grytviken -54.2811  -36.5092      2.15        96         100
# 3                   namibe -15.1961   12.1522     19.91        79           5
# 5                inhambane -23.8650   35.3833     22.17        94           1
# 9                adamstown -25.0660 -130.1015     19.65        62         100
# 10       port-aux-francais -49.3500   70.2167      2.95        73          23
#
#          Wind Speed Country        Date
# City_ID
# 2              2.43      GS  1729541746
# 3              1.82      AO  1729541747
# 5              3.11      MZ  1729541749
# 9              6.75      PN  1729541754
# 10            13.88      TF  1729541755

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
title = "Latitude vs Max Temp"
x_label = "Latitude"
y_label = "Max Temp"
linear_reg_plot(x_values, y_values, title, x_label, y_label)
# Out:
# The r^2-value is: 0.6280582781311658

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
title = "Latitude vs Max Temp"
x_label = "Latitude"
y_label = "Max Temp"
linear_reg_plot(x_values, y_values, title, x_label, y_label)
# Out:
# The r^2-value is: 0.43357415407820216

# %% [markdown]
# **Discussion about the linear relationship:**
# - Northern Hemisphere: There is a strong correlation between latitude and maximum temperature, indicated by an r^2 value of 0.628. The maximum temperature decreases by 0.52°C per degree of latitude increase in the Northern Hemisphere, indicating the temperature drops as we move further away from the equator.
# - Southern Hemisphere: The correlation is weaker compared to the Northern Hemisphere. There is a moderate correlation between latitude and maximum temperature, indicated by an r^2 value of 0.434. In the Southern Hemisphere, the maximum temperature increases by 0.32°C per degree of latitude increase, indicating that temperatures rise as we move towards the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
title = "Latitude vs Humidity"
x_label = "Latitude"
y_label = "Humidity"
linear_reg_plot(x_values, y_values, title, x_label, y_label)
# Out:
# The r^2-value is: 0.03636731535053676

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
title = "Latitude vs Humidity"
x_label = "Latitude"
y_label = "Humidity"
linear_reg_plot(x_values, y_values, title, x_label, y_label)
# Out:
# The r^2-value is: 1.4621774917490483e-05

# %% [markdown]
# **Discussion about the linear relationship:** The r^2 values from the linear regressions for the Northern and Southern Hemispheres are 0.0364 and 1.462e-05, respectively, which are very low. This indicates that there is very weak to no correlation between latitude and humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
title = "Latitude vs Cloudiness"
x_label = "Latitude"
y_label = "Cloudiness"
linear_reg_plot(x_values, y_values, title, x_label, y_label)
# Out:
# The r^2-value is: 0.02068947484012171

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
title = "Latitude vs Cloudiness"
x_label = "Latitude"
y_label = "Cloudiness"
linear_reg_plot(x_values, y_values, title, x_label, y_label)
# Out:
# The r^2-value is: 0.014829140296798077

# %% [markdown]
# **Discussion about the linear relationship:** The r^2 values from the linear regressions for the Northern and Southern Hemispheres are 0.0207 and 0.0148, respectively, which are very low. This indicates that there is very weak to no correlation between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
title = "Latitude vs Wind Speed"
x_label = "Latitude"
y_label = "Wind Speed"
linear_reg_plot(x_values, y_values, title, x_label, y_label)
# Out:
# The r^2-value is: 0.007820935166201153

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
title = "Latitude vs Wind Speed"
x_label = "Latitude"
y_label = "Wind Speed"
linear_reg_plot(x_values, y_values, title, x_label, y_label)
# Out:
# The r^2-value is: 0.147226918431727

# %% [markdown]
# **Discussion about the linear relationship:** The r^2 values from the linear regressions for the Northern and Southern Hemispheres are 0.00782 and 0.147, respectively, which are very low. This indicates that there is very weak to no correlation between latitude and wind speed.
